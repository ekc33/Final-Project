# %% [markdown]
# For my metric I took a look at rent prices per neighborhood because it is one of the most important factors people look at when chosing their place to live in. Consequently, we look at the neighborhoods in Pittsburgh that have the cheapest rent on average.

# %% [markdown]
# # Map representation of rent prices per neighborhood
# ![alt text](Prices.png "Map")

# %%
df1 = pd.read_csv("contract-rent.csv")

r = df1[df1['Estimate; Total:'] < 500]

r = r.dropna()

r.plot.bar(x = 'Neighborhood', y = 'Estimate; Total:').set_title('Neighborhoods with rent less than $500')
# Out:
# Text(0.5, 1.0, 'Neighborhoods with rent less than $500')

# %% [markdown]
# # The neighborhood with the cheapest housing is: Chataeu
