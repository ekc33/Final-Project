# %%
import pandas as pd
parks = pd.read_csv("park_data.csv")

parks = parks[(parks["type"] == "Park") | (parks["type"] == "Open Space")]
pd.set_option('display.max_columns', None)
parks.head(210)
# Out:
#              id                     name        type  \
# 0    2111959181           Able Long Park        Park
# 1    1109513049  Albert Turk Graham Park        Park
# 2    1544096765               Alcoa Park        Park
# 3    1212681573        Allegheny Commons        Park
# 4     954863286   Allegheny Landing Park        Park
# ..          ...                      ...         ...
# 204  1460363095           Woods Run Park        Park
# 205   930068146         Young Field Park        Park
# 206  1127012019              Zulema Park        Park
# 207  1719897212       Liberty Green Park        Park
# 208  1305573349         Esser Plaza Park  Open Space
#
#     maintenance_responsibility  \
# 0             Parks - Southern
# 1             Parks - Schenley
# 2             Parks - Northern
# 3             Parks - Northern
# 4             Parks - Northern
# ..                         ...
# 204           Parks - Northern
# 205           Parks - Northern
# 206           Parks - Schenley
# 207          Parks - Northeast
# 208           Parks - Southern
#
#                                                  image        neighborhood  \
# 0    https://tools.wprdc.org/images/pittsburgh/park...           Beechview
# 1    https://tools.wprdc.org/images/pittsburgh/park...    Crawford-Roberts
# 2                                                  NaN         North Shore
# 3                                                  NaN    Allegheny Center
# 4                                                  NaN         North Shore
# ..                                                 ...                 ...
# 204  https://tools.wprdc.org/images/pittsburgh/park...  Marshall-Shadeland
# 205                                                NaN  Marshall-Shadeland
# 206                                                NaN     Central Oakland
# 207                                                NaN        East Liberty
# 208                                                NaN    South Side Flats
#
#      council_district  ward        tract  public_works_division  pli_division  \
# 0                   4    19  42003192000                      5            19
# 1                   6     3  42003030500                      3             3
# 2                   1    22  42003563200                      6            22
# 3                   1    22  42003562700                      1            22
# 4                   1    22  42003563200                      6            22
# ..                ...   ...          ...                    ...           ...
# 204                 1    27  42003271500                      1            27
# 205                 1    27  42003271500                      1            27
# 206                 3     4  42003040500                      3             4
# 207                 9    11  42003111500                      2            11
# 208                 3    17  42003170200                      3            17
#
#      police_zone fire_zone   latitude  longitude
# 0              6      4-28  40.408118 -80.028197
# 1              2       2-1  40.440507 -79.984018
# 2              1      1-20  40.447481 -80.001017
# 3              1       1-7  40.453126 -80.009158
# 4              1      1-20  40.447184 -80.002907
# ..           ...       ...        ...        ...
# 204            1      1-14  40.476383 -80.029253
# 205            1      1-14  40.472963 -80.032768
# 206            4      2-14  40.435693 -79.957048
# 207            5      3-10  40.462773 -79.919314
# 208            3      4-24  40.428564 -79.986239
#
# [159 rows x 15 columns]

# %%
parks = pd.read_csv("park_data.csv")
count = parks["neighborhood"].value_counts()
count
# Out:
# East Liberty                 12
# Central Business District    10
# Beechview                     8
# South Side Slopes             7
# Point Breeze                  7
#                              ..
# Hays                          1
# Arlington                     1
# Stanton Heights               1
# Morningside                   1
# Squirrel Hill North           1
# Name: neighborhood, Length: 73, dtype: int64

# %%
import matplotlib.pyplot as plotter

import numpy as np

objectTypes     = ('Point Breeze', 'South Side Slopes', 'Beechview', 'Central Business District', 'East Liberty')
yAxisCategories = np.arange(len(objectTypes))
objectCount     = (7, 7, 8, 10, 12)
stdDeviation    = (0, 0, 0, 0, 0) 

figureObject, axesObject    = plotter.subplots()

hBarChart                   = plotter.barh(yAxisCategories,

                                           objectCount,

                                           xerr=stdDeviation,

                                           align='center',

                                           color='blue',

                                           ecolor='blue')

axesObject.set_title('Amount of all types of parks in Pittsburgh per city')

axesObject.set_yticks(yAxisCategories)

axesObject.set_yticklabels(objectTypes)

axesObject.set_xlabel('Park Count')

 

plotter.show()

# %%
parks = pd.read_csv("park_data.csv")
parks = parks[(parks["type"] == "Park") | (parks["type"] == "Open Space")]
count = parks["neighborhood"].value_counts()
count
# Out:
# Beechview              6
# South Side Slopes      6
# Troy Hill              5
# Hazelwood              5
# Mount Washington       5
#                       ..
# Stanton Heights        1
# Bedford Dwellings      1
# Fairywood              1
# Esplen                 1
# Squirrel Hill North    1
# Name: neighborhood, Length: 71, dtype: int64

# %%
import matplotlib.pyplot as plotter

import numpy as np

objectTypes     = ('Mount Washington', 'Hazelwood', 'Troy Hill', 'South Side Slopes', 'Beechview')
yAxisCategories = np.arange(len(objectTypes))
objectCount     = (5, 5, 5, 6, 6)
stdDeviation    = (0, 0, 0, 0, 0) 

figureObject, axesObject    = plotter.subplots()

hBarChart                   = plotter.barh(yAxisCategories,

                                           objectCount,

                                           xerr=stdDeviation,

                                           align='center',

                                           color='gold',

                                           ecolor='blue')

axesObject.set_title('Amount of parks/open space in Pittsburgh per city')

axesObject.set_yticks(yAxisCategories)

axesObject.set_yticklabels(objectTypes)

axesObject.set_xlabel('Park Count')

 

plotter.show()

# %% [markdown]
# #### First, to grab all of my info and display it, I use a format that the max amount is larger than its maximum number. I then have a filter that only focuses on the values of "open spaces" and "parks," taking away the traffic circles, monuments, and more. I then also include the data in a smaller table with numbers and no other data, including the previous data, without the filter to see other opportunities from differing neighborhoods. Finally, I use matplotlib to display both datasets and compare using different colors to show the importance of the type of data used.
